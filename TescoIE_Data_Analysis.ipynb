# %% [markdown]
# # Tesco Clubcard Data Analysis Notebook
#
# This notebook serves to help me understand how the JSON file provided of Tesco Clubcard user data is structured and what various information can be drawn from it. I must pre-process, parse through, and identify key figures from the JSON data of transactions from a user's clubcard.

# %% [markdown]
# ## Imports

# %%
import json
import pandas as pd

# %% [markdown]
# ## Load Transactions from JSON into DF

# %%
# Load raw JSON
with open("../../Downloads/Tesco-Customer-Data.json", "r") as json_file: 
    json_data = json.load(json_file)

# Extract Transactions
transactions = json_data["Purchase"][0]

#Create Trnasaction_DF
df_transactions = pd.json_normalize(transactions)
df_transactions.head()
# Out:
#   basketValueGross purchaseType overallBasketSavings storeId  \
# 0              5.2     IN_STORE                 1.35    4667
# 1             4.74     IN_STORE                 1.06    5980
# 2             3.45     IN_STORE                  0.7    5505
# 3             3.45     IN_STORE                  0.7    5980
# 4              4.9     IN_STORE                 0.85    4667
#
#                                         storeAddress  \
# 0  Units 2&3 Distillers Building,Smithfield, Dubl...
# 1                              51 - 52 Thomas Street
# 2                             41 Upper Camden Street
# 3                              51 - 52 Thomas Street
# 4  Units 2&3 Distillers Building,Smithfield, Dubl...
#
#                                          paymentType                timeStamp  \
# 0  [{'type': 'VisaCredit', 'category': 'NA', 'amo...  2024-12-15 17:17:32.514
# 1  [{'type': 'VisaCredit', 'category': 'NA', 'amo...  2024-12-12 16:04:56.304
# 2  [{'type': 'VisaCredit', 'category': 'NA', 'amo...  2024-12-06 17:59:38.685
# 3  [{'type': 'VisaCredit', 'category': 'NA', 'amo...  2024-12-06 14:47:26.859
# 4  [{'type': 'VisaCredit', 'category': 'NA', 'amo...  2024-11-28 19:40:34.480
#
#   basketValueNet says              storeName storeFormat  \
# 0            5.2   NA     Smithfield Express     Express
# 1           0.74   NA  Thomas Street Express     Express
# 2           3.45   NA  Camden Street Express     Express
# 3           3.45   NA  Thomas Street Express     Express
# 4            4.9   NA     Smithfield Express     Express
#
#                                              product
# 0  [{'name': 'Tesco Slievenamon Irish Still Sprin...
# 1  [{'name': 'Kerrygold Butter Sticks 100G', 'qua...
# 2  [{'name': 'Tesco Slievenamon Irish Still Sprin...
# 3  [{'name': 'Tesco Slievenamon Irish Still Sprin...
# 4  [{'name': 'Cadbury Dairy Milk Whole Nut Chocol...

# %% [markdown]
# ## Initial Data Analysis

# %%
# Convert timeStamp column to datetime and handle that some are formatted differently
df_transactions["timeStamp"] = pd.to_datetime(df_transactions["timeStamp"], format="mixed", utc=True)

# %%
print("First Transaction Date:", df_transactions["timeStamp"].min())
print("Last Transaction Date:", df_transactions["timeStamp"].max())
print("Number of Transactions:", len(df_transactions))
print("Account Open for %d days" % ((df_transactions["timeStamp"].max() - df_transactions["timeStamp"].min()).days))
print("Visited %d different stores." % (len(df_transactions["storeId"].unique())))
# Out:
# First Transaction Date: 2019-09-11 18:46:52+00:00
# Last Transaction Date: 2024-12-15 17:17:32.514000+00:00
# Number of Transactions: 250
# Account Open for 1921 days
# Visited 17 different stores.

# %%
# View all the different stores visited
df_transactions["storeName"].unique()
# Out:
# array(['Smithfield Express', 'Thomas Street Express',
#        'Camden Street Express', 'Crumlin Express', 'Castlebar Superstore',
#        'Spencer Dock Express', 'Temple Bar Express',
#        'Baggot Street Upper Metro', 'Dorset Street Express',
#        'Cabra Superstore', 'Donnybrook Express', 'Bloomfields Superstore',
#        'Parnell Street Metro', 'Merrion Superstore', 'BLOOMFIELDS',
#        'CABRA', 'FINGLAS CLEARWATER', 'MERRION', 'TEMPLE BAR METRO',
#        'THOMAS STREET EXPRESS', 'DONNYBROOK EXPRESS', 'STILLORGAN',
#        'TALBOT STREET EXPRESS'], dtype=object)

# %% [markdown]
# ###

# %%
# Fix issue of Cabra listed under differet names 
df_transactions["storeName"] = df_transactions["storeName"].replace(
    {"CABRA": "Cabra Superstore"}
)

# %%
# Top 5 stores visited and # of times
df_transactions["storeName"].value_counts().head().reset_index(name="visits")
# Out:
#                storeName  visits
# 0                MERRION      69
# 1       Cabra Superstore      67
# 2  Thomas Street Express      43
# 3     Smithfield Express      22
# 4             STILLORGAN       9

# %%
# Save Cleaned Dataset 
df_transactions.to_json("../Tesco-Customer-Data-CLEANED.json", orient="records", indent=4)

# %% [markdown]
# ## Transaction Analysis

# %%
# Create DF of items
items_rows = []

for _, tx in df_transactions.iterrows():
    for item in tx["product"]:
        items_rows.append({
            "transaction_time": tx["timeStamp"],
            "store": tx["storeName"],
            "item": item["name"],
            "quantity": int(item["quantity"]),
            "price": float(item["price"])
        })
df_items = pd.DataFrame(items_rows)
df_items
# Out:
#                      transaction_time                  store  \
# 0    2024-12-15 17:17:32.514000+00:00     Smithfield Express
# 1    2024-12-15 17:17:32.514000+00:00     Smithfield Express
# 2    2024-12-15 17:17:32.514000+00:00     Smithfield Express
# 3    2024-12-12 16:04:56.304000+00:00  Thomas Street Express
# 4    2024-12-12 16:04:56.304000+00:00  Thomas Street Express
# ...                               ...                    ...
# 2342        2019-09-11 18:46:52+00:00                MERRION
# 2343        2019-09-11 18:46:52+00:00                MERRION
# 2344        2019-09-11 18:46:52+00:00                MERRION
# 2345        2019-09-11 18:46:52+00:00                MERRION
# 2346        2019-09-11 18:46:52+00:00                MERRION
#
#                                                    item  quantity  price
# 0     Tesco Slievenamon Irish Still Spring Water 2 L...         1   0.95
# 1       Cadbury Dairy Milk Chocolate Whole Nut Bar 120G         1   1.75
# 2           Keogh's Crinkle Cut Crisps Salt&Vinegar125g         1   2.50
# 3                          Kerrygold Butter Sticks 100G         1   0.20
# 4     Tesco Slievenamon Irish Still Spring Water 2 L...         1   0.15
# ...                                                 ...       ...    ...
# 2342           Tesco Health Chicken Curry And Rice 350G         1   1.50
# 2343                               Tesco Fine Bean 200G         1   1.15
# 2344                   Tesco Kitchen Towel White 4 Roll         1   1.19
# 2345                           Tesco Fusilli Pasta 500G         1   0.49
# 2346              Tesco Irish Family Meatball Pack 720G         1   4.00
#
# [2347 rows x 5 columns]

# %%
df_items.groupby('item')['quantity'].sum().sort_values(ascending=False).head(30)
# Out:
# item
# Tesco Irish Beef Sirloin Steak 266G                       173
# Tesco Microwave Pilau Rice 250G                            75
# Tesco Bananas Loose                                        62
# Tesco Hot Salsa 300G                                       60
# Tesco Gala Apple 7 Pack                                    59
# Tesco Mini Carrot 320G                                     57
# Tesco Fresh Potato Gnocchi Pasta 400 G                     54
# Tesco Lightly Salted Tortilla Chips 200G                   48
# Tesco Spinach 90G                                          46
# Tesco Egg Rice 250G                                        41
# Hearty Food Co. Chicken Flavour Noodles 65G                41
# Glenisk Fresh Goats Milk 1 Litre                           39
# Springforce Jumbo Kitchen Towel 2 Roll                     36
# Tesco Mixed Peppers 3 Pack                                 33
# Tesco Irish Smoked Streaky Rashers 253G                    33
# Tesco Family Pack Onions 1 Kilograms                       32
# Tesco Big Buy Traditional Irish Ham 320G                   30
# Tesco Microwave Long Grain Rice 250G                       29
# Tesco Pepperoni Pizza 280G                                 27
# Halls Extra Strong Mentho-Lyptus Hard Boiled Sweets 9s     26
# Tesco Asparagus Tips 125G (C)                              25
# Keogh's Crinkle Cut Crisps Salt&Vinegar125g                24
# Tesco Corn Tortillas X8 320G                               24
# Tesco Slievenamon Irish Still Spring Water 2 Litre         23
# Tesco Chicken Mini Fillets 450G                            23
# Tesco Chicken Mini Fillets 390G                            22
# Bagu Naturally Sweet Easy Peelers 600G                     22
# Tesco Fun-Sized Easy Peeler Pack 600G                      21
# Tesco Fire Pit Beef Sirloin Steak 266g                     21
# Tesco Lemon Net 4 Pack                                     21
# Name: quantity, dtype: int64

# %%
# Mapping to fix items that are the same but listed under different Titles
mapping = {
    "Tesco Irish Beef Sirloin Steak 266G": "Tesco Beef Sirloin Steak 266G",
    "Tesco Fire Pit Beef Sirloin Steak 266g": "Tesco Beef Sirloin Steak 266G",
}
df_items["item"] = df_items["item"].replace(mapping)

# %%
df_items.groupby('item')['quantity'].sum().sort_values(ascending=False).head(50)
# Out:
# item
# Tesco Beef Sirloin Steak 266G                                  194
# Tesco Microwave Pilau Rice 250G                                 75
# Tesco Bananas Loose                                             62
# Tesco Hot Salsa 300G                                            60
# Tesco Gala Apple 7 Pack                                         59
# Tesco Mini Carrot 320G                                          57
# Tesco Fresh Potato Gnocchi Pasta 400 G                          54
# Tesco Lightly Salted Tortilla Chips 200G                        48
# Tesco Spinach 90G                                               46
# Hearty Food Co. Chicken Flavour Noodles 65G                     41
# Tesco Egg Rice 250G                                             41
# Glenisk Fresh Goats Milk 1 Litre                                39
# Springforce Jumbo Kitchen Towel 2 Roll                          36
# Tesco Irish Smoked Streaky Rashers 253G                         33
# Tesco Mixed Peppers 3 Pack                                      33
# Tesco Family Pack Onions 1 Kilograms                            32
# Tesco Big Buy Traditional Irish Ham 320G                        30
# Tesco Microwave Long Grain Rice 250G                            29
# Tesco Pepperoni Pizza 280G                                      27
# Halls Extra Strong Mentho-Lyptus Hard Boiled Sweets 9s          26
# Tesco Asparagus Tips 125G (C)                                   25
# Keogh's Crinkle Cut Crisps Salt&Vinegar125g                     24
# Tesco Corn Tortillas X8 320G                                    24
# Tesco Slievenamon Irish Still Spring Water 2 Litre              23
# Tesco Chicken Mini Fillets 450G                                 23
# Tesco Chicken Mini Fillets 390G                                 22
# Bagu Naturally Sweet Easy Peelers 600G                          22
# Tesco Lemon Net 4 Pack                                          21
# Tesco Fun-Sized Easy Peeler Pack 600G                           21
# Tesco Medium Irish Egg 18 Pack                                  20
# Cadbury Dairy Milk Chocolate Fruit & Nut Bar 140G               19
# Tesco Strawberry Sensation Smoothie 750Ml                       18
# Tesco Irish Beef Sirloin Steak 800G                             18
# Tesco Longlife Almond Drink Unsweetened 1Ltr                    17
# Tesco Mexican Inspired Rice 250G                                17
# Tesco 12 Potato Waffles 680G                                    17
# Tesco Mild Spinach 200G                                         16
# Halls Soothers Honey & Lemon Sweets with Liquid Centres 45g     15
# Tesco Citrus Antibacterial Wipes 40 Wipes                       15
# Tesco Broccoli Florets 1Kg                                      14
# Monster Energy Ultra Z/Sgr Drink 4 X 500Ml                      14
# Tesco Irish Beef Burgers 600G                                   14
# Nando's Medium Peri Peri Marinade 262G                          14
# Tesco Irish Classics Cottage Pie/Veg 500G                       14
# Tesco Dark Chocolate Chips 100G                                 13
# Keogh's Crisps Atlantic Seas&I Cidervinegar125g                 12
# Tesco Carrot Bag 500G                                           12
# Tesco Irish Gala Apples 6 Pack                                  12
# Mccloskey's Boyne Sourdough Bread 550G                          12
# Tesco Chicken And Vegetable Soup 400G                           12
# Name: quantity, dtype: int64
